# %%
# Import modules
import pandas as pd
import re
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# NOTE: Combine functions into a class later.

# %%
# Import data
df = pd.read_csv('../data/processed_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  pos    artist_name               track_uri  \
# 0             0           0    0  Missy Elliott  0UaMYEvWZi0ZqiDOoHU3YI
# 1             1        7734   73  Missy Elliott  0UaMYEvWZi0ZqiDOoHU3YI
# 2             2       14037   14  Missy Elliott  0UaMYEvWZi0ZqiDOoHU3YI
# 3             3       21536   42  Missy Elliott  0UaMYEvWZi0ZqiDOoHU3YI
# 4             4       24404    1  Missy Elliott  0UaMYEvWZi0ZqiDOoHU3YI
#
#                               artist_uri  \
# 0  spotify:artist:2wIVse2owClT7go1WT98tk
# 1  spotify:artist:2wIVse2owClT7go1WT98tk
# 2  spotify:artist:2wIVse2owClT7go1WT98tk
# 3  spotify:artist:2wIVse2owClT7go1WT98tk
# 4  spotify:artist:2wIVse2owClT7go1WT98tk
#
#                                    track_name  \
# 0  Lose Control (feat. Ciara & Fat Man Scoop)
# 1  Lose Control (feat. Ciara & Fat Man Scoop)
# 2  Lose Control (feat. Ciara & Fat Man Scoop)
# 3  Lose Control (feat. Ciara & Fat Man Scoop)
# 4  Lose Control (feat. Ciara & Fat Man Scoop)
#
#                               album_uri  duration_ms_x    album_name  ...  \
# 0  spotify:album:6vV5UrXcfyQD1wu4Qo2I9K         226863  The Cookbook  ...
# 1  spotify:album:6vV5UrXcfyQD1wu4Qo2I9K         226863  The Cookbook  ...
# 2  spotify:album:6vV5UrXcfyQD1wu4Qo2I9K         226863  The Cookbook  ...
# 3  spotify:album:6vV5UrXcfyQD1wu4Qo2I9K         226863  The Cookbook  ...
# 4  spotify:album:6vV5UrXcfyQD1wu4Qo2I9K         226863  The Cookbook  ...
#
#              type                      id  \
# 0  audio_features  0UaMYEvWZi0ZqiDOoHU3YI
# 1  audio_features  0UaMYEvWZi0ZqiDOoHU3YI
# 2  audio_features  0UaMYEvWZi0ZqiDOoHU3YI
# 3  audio_features  0UaMYEvWZi0ZqiDOoHU3YI
# 4  audio_features  0UaMYEvWZi0ZqiDOoHU3YI
#
#                                     uri  \
# 0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 2  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 3  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 4  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0UaMYEvWZi0Z...
# 1  https://api.spotify.com/v1/tracks/0UaMYEvWZi0Z...
# 2  https://api.spotify.com/v1/tracks/0UaMYEvWZi0Z...
# 3  https://api.spotify.com/v1/tracks/0UaMYEvWZi0Z...
# 4  https://api.spotify.com/v1/tracks/0UaMYEvWZi0Z...
#
#                                         analysis_url  duration_ms_y  \
# 0  https://api.spotify.com/v1/audio-analysis/0UaM...         226864
# 1  https://api.spotify.com/v1/audio-analysis/0UaM...         226864
# 2  https://api.spotify.com/v1/audio-analysis/0UaM...         226864
# 3  https://api.spotify.com/v1/audio-analysis/0UaM...         226864
# 4  https://api.spotify.com/v1/audio-analysis/0UaM...         226864
#
#    time_signature  artist_pop  \
# 0               4          74
# 1               4          74
# 2               4          74
# 3               4          74
# 4               4          74
#
#                                               genres  track_pop
# 0  dance_pop hip_hop hip_pop pop pop_rap r&b rap ...         69
# 1  dance_pop hip_hop hip_pop pop pop_rap r&b rap ...         69
# 2  dance_pop hip_hop hip_pop pop pop_rap r&b rap ...         69
# 3  dance_pop hip_hop hip_pop pop pop_rap r&b rap ...         69
# 4  dance_pop hip_hop hip_pop pop pop_rap r&b rap ...         69
#
# [5 rows x 32 columns]

# %% [markdown]
# It's expected that there might be duplicates of songs inside the data because there exists some songs that were made by different artists but have the same title.

# %% [markdown]
# ## Data Pre-processing

# %%
# Drop duplicate songs through combining artist and song

def drop_duplicate_songs(df: pd.DataFrame):
    """
     Drops duplicate songs that exist due to different songs containing the same title.
    """
    df['artist_song'] = df.apply(lambda row: row['artist_name']+row['track_name'],axis = 1)
    return df.drop_duplicates(subset='artist_song')

print(f'Number of songs before removing duplicates: {len(df)}')
df = drop_duplicate_songs(df)
print(f'Number of songs after removing duplicates: {len(df)}')
# Out:
# Number of songs before removing duplicates:        Unnamed: 0.1  Unnamed: 0  pos    artist_name               track_uri  \
# 0                 0           0    0  Missy Elliott  0UaMYEvWZi0ZqiDOoHU3YI
# 1                 1        7734   73  Missy Elliott  0UaMYEvWZi0ZqiDOoHU3YI
# 2                 2       14037   14  Missy Elliott  0UaMYEvWZi0ZqiDOoHU3YI
# 3                 3       21536   42  Missy Elliott  0UaMYEvWZi0ZqiDOoHU3YI
# 4                 4       24404    1  Missy Elliott  0UaMYEvWZi0ZqiDOoHU3YI
# ...             ...         ...  ...            ...                     ...
# 67494         67494       67496   37          Jon D  3uCHI1gfOUL5j5swEh0TcH
# 67495         67495       67499   40      Big Words  0P1oO2gREMYUCoOkzYAyFu
# 67496         67496       67500   41   Allan Rayman  2oM4BuruDnEvk59IvIXCwn
# 67497         67497       67501   42      Jon Jason  4Ri5TTUgjM96tbQZd5Ua7V
# 67498         67498       67502   43       Grizfolk  5RVuBrXVLptAEbGJdSDzL5
#
#                                   artist_uri  \
# 0      spotify:artist:2wIVse2owClT7go1WT98tk
# 1      spotify:artist:2wIVse2owClT7go1WT98tk
# 2      spotify:artist:2wIVse2owClT7go1WT98tk
# 3      spotify:artist:2wIVse2owClT7go1WT98tk
# 4      spotify:artist:2wIVse2owClT7go1WT98tk
# ...                                      ...
# 67494  spotify:artist:5HCypjplgh5uQezvBpOfXN
# 67495  spotify:artist:0sHN89qak07mnug3LVVjzP
# 67496  spotify:artist:6Yv6OBXD6ZQakEljaGaDAk
# 67497  spotify:artist:77bNdkKYBBmc30CisCA6tE
# 67498  spotify:artist:6Xa4nbrSTfbioA4lLShbjh
#
#                                          track_name  \
# 0        Lose Control (feat. Ciara & Fat Man Scoop)
# 1        Lose Control (feat. Ciara & Fat Man Scoop)
# 2        Lose Control (feat. Ciara & Fat Man Scoop)
# 3        Lose Control (feat. Ciara & Fat Man Scoop)
# 4        Lose Control (feat. Ciara & Fat Man Scoop)
# ...                                             ...
# 67494                                  I Don't Know
# 67495                                    The Answer
# 67496                                         25.22
# 67497                                  Good Feeling
# 67498  Cosmic Angel - Acoustic From Capitol Studios
#
#                                   album_uri  duration_ms_x  \
# 0      spotify:album:6vV5UrXcfyQD1wu4Qo2I9K         226863
# 1      spotify:album:6vV5UrXcfyQD1wu4Qo2I9K         226863
# 2      spotify:album:6vV5UrXcfyQD1wu4Qo2I9K         226863
# 3      spotify:album:6vV5UrXcfyQD1wu4Qo2I9K         226863
# 4      spotify:album:6vV5UrXcfyQD1wu4Qo2I9K         226863
# ...                                     ...            ...
# 67494  spotify:album:2KEQtuVl1cYsTYtVRUrNVi         189183
# 67495  spotify:album:5jrsRHRAmetu5e7RRBoxj7         263679
# 67496  spotify:album:3CbNgBzI7r9o0F6VjH9sTY         189213
# 67497  spotify:album:2dZ7oVNQBeLlpoUYfbEsJP         194720
# 67498  spotify:album:7D6Y19tjm4DQNch39FeWpO         257194
#
#                                album_name  ...            type  \
# 0                            The Cookbook  ...  audio_features
# 1                            The Cookbook  ...  audio_features
# 2                            The Cookbook  ...  audio_features
# 3                            The Cookbook  ...  audio_features
# 4                            The Cookbook  ...  audio_features
# ...                                   ...  ...             ...
# 67494                               Roots  ...  audio_features
# 67495  Hollywood, a Beautiful Coincidence  ...  audio_features
# 67496                        Roadhouse 01  ...  audio_features
# 67497                        Good Feeling  ...  audio_features
# 67498                        Cosmic Angel  ...  audio_features
#
#                            id                                   uri  \
# 0      0UaMYEvWZi0ZqiDOoHU3YI  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1      0UaMYEvWZi0ZqiDOoHU3YI  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 2      0UaMYEvWZi0ZqiDOoHU3YI  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 3      0UaMYEvWZi0ZqiDOoHU3YI  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 4      0UaMYEvWZi0ZqiDOoHU3YI  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# ...                       ...                                   ...
# 67494  3uCHI1gfOUL5j5swEh0TcH  spotify:track:3uCHI1gfOUL5j5swEh0TcH
# 67495  0P1oO2gREMYUCoOkzYAyFu  spotify:track:0P1oO2gREMYUCoOkzYAyFu
# 67496  2oM4BuruDnEvk59IvIXCwn  spotify:track:2oM4BuruDnEvk59IvIXCwn
# 67497  4Ri5TTUgjM96tbQZd5Ua7V  spotify:track:4Ri5TTUgjM96tbQZd5Ua7V
# 67498  5RVuBrXVLptAEbGJdSDzL5  spotify:track:5RVuBrXVLptAEbGJdSDzL5
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/0UaMYEvWZi0Z...
# 1      https://api.spotify.com/v1/tracks/0UaMYEvWZi0Z...
# 2      https://api.spotify.com/v1/tracks/0UaMYEvWZi0Z...
# 3      https://api.spotify.com/v1/tracks/0UaMYEvWZi0Z...
# 4      https://api.spotify.com/v1/tracks/0UaMYEvWZi0Z...
# ...                                                  ...
# 67494  https://api.spotify.com/v1/tracks/3uCHI1gfOUL5...
# 67495  https://api.spotify.com/v1/tracks/0P1oO2gREMYU...
# 67496  https://api.spotify.com/v1/tracks/2oM4BuruDnEv...
# 67497  https://api.spotify.com/v1/tracks/4Ri5TTUgjM96...
# 67498  https://api.spotify.com/v1/tracks/5RVuBrXVLptA...
#
#                                             analysis_url  duration_ms_y  \
# 0      https://api.spotify.com/v1/audio-analysis/0UaM...         226864
# 1      https://api.spotify.com/v1/audio-analysis/0UaM...         226864
# 2      https://api.spotify.com/v1/audio-analysis/0UaM...         226864
# 3      https://api.spotify.com/v1/audio-analysis/0UaM...         226864
# 4      https://api.spotify.com/v1/audio-analysis/0UaM...         226864
# ...                                                  ...            ...
# 67494  https://api.spotify.com/v1/audio-analysis/3uCH...         189184
# 67495  https://api.spotify.com/v1/audio-analysis/0P1o...         263680
# 67496  https://api.spotify.com/v1/audio-analysis/2oM4...         189213
# 67497  https://api.spotify.com/v1/audio-analysis/4Ri5...         194720
# 67498  https://api.spotify.com/v1/audio-analysis/5RVu...         257195
#
#        time_signature  artist_pop  \
# 0                   4          74
# 1                   4          74
# 2                   4          74
# 3                   4          74
# 4                   4          74
# ...               ...         ...
# 67494               4          47
# 67495               4          39
# 67496               4          55
# 67497               4           4
# 67498               4          53
#
#                                                   genres  track_pop
# 0      dance_pop hip_hop hip_pop pop pop_rap r&b rap ...         69
# 1      dance_pop hip_hop hip_pop pop pop_rap r&b rap ...         69
# 2      dance_pop hip_hop hip_pop pop pop_rap r&b rap ...         69
# 3      dance_pop hip_hop hip_pop pop pop_rap r&b rap ...         69
# 4      dance_pop hip_hop hip_pop pop pop_rap r&b rap ...         69
# ...                                                  ...        ...
# 67494                                            unknown         27
# 67495                                     australian_r&b         37
# 67496  canadian_contemporary_r&b modern_alternative_rock         49
# 67497                                            unknown         16
# 67498  indie_poptimism indiecoustica modern_alternati...         40
#
# [67499 rows x 32 columns]
# Number of songs after removing duplicates:        Unnamed: 0.1  Unnamed: 0  pos        artist_name  \
# 0                 0           0    0      Missy Elliott
# 6                 6           1    1     Britney Spears
# 19               19           2    2            Beyoncé
# 46               46           3    3  Justin Timberlake
# 55               55           4    4             Shaggy
# ...             ...         ...  ...                ...
# 67494         67494       67496   37              Jon D
# 67495         67495       67499   40          Big Words
# 67496         67496       67500   41       Allan Rayman
# 67497         67497       67501   42          Jon Jason
# 67498         67498       67502   43           Grizfolk
#
#                     track_uri                             artist_uri  \
# 0      0UaMYEvWZi0ZqiDOoHU3YI  spotify:artist:2wIVse2owClT7go1WT98tk
# 6      6I9VzXrHxO9rA9A5euc8Ak  spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 19     0WqIKmW4BTrj3eJFmnCKMv  spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 46     1AWQoqb9bSvzTjaLralEkT  spotify:artist:31TPClRtHm23RisEBtV3X7
# 55     1lzr43nnXAijIGYnCT8M8H  spotify:artist:5EvFsr3kj42KNv97ZEnqij
# ...                       ...                                    ...
# 67494  3uCHI1gfOUL5j5swEh0TcH  spotify:artist:5HCypjplgh5uQezvBpOfXN
# 67495  0P1oO2gREMYUCoOkzYAyFu  spotify:artist:0sHN89qak07mnug3LVVjzP
# 67496  2oM4BuruDnEvk59IvIXCwn  spotify:artist:6Yv6OBXD6ZQakEljaGaDAk
# 67497  4Ri5TTUgjM96tbQZd5Ua7V  spotify:artist:77bNdkKYBBmc30CisCA6tE
# 67498  5RVuBrXVLptAEbGJdSDzL5  spotify:artist:6Xa4nbrSTfbioA4lLShbjh
#
#                                          track_name  \
# 0        Lose Control (feat. Ciara & Fat Man Scoop)
# 6                                             Toxic
# 19                                    Crazy In Love
# 46                                   Rock Your Body
# 55                                     It Wasn't Me
# ...                                             ...
# 67494                                  I Don't Know
# 67495                                    The Answer
# 67496                                         25.22
# 67497                                  Good Feeling
# 67498  Cosmic Angel - Acoustic From Capitol Studios
#
#                                   album_uri  duration_ms_x  \
# 0      spotify:album:6vV5UrXcfyQD1wu4Qo2I9K         226863
# 6      spotify:album:0z7pVBGOD7HCIB7S8eLkLI         198800
# 19     spotify:album:25hVFAxTlDvXbx2X2QkUkE         235933
# 46     spotify:album:6QPkyl04rXwTGlGlcYaRoW         267266
# 55     spotify:album:6NmFmPX56pcLBOFMhIiKvF         227600
# ...                                     ...            ...
# 67494  spotify:album:2KEQtuVl1cYsTYtVRUrNVi         189183
# 67495  spotify:album:5jrsRHRAmetu5e7RRBoxj7         263679
# 67496  spotify:album:3CbNgBzI7r9o0F6VjH9sTY         189213
# 67497  spotify:album:2dZ7oVNQBeLlpoUYfbEsJP         194720
# 67498  spotify:album:7D6Y19tjm4DQNch39FeWpO         257194
#
#                                          album_name  ...  \
# 0                                      The Cookbook  ...
# 6                                       In The Zone  ...
# 19     Dangerously In Love (Alben für die Ewigkeit)  ...
# 46                                        Justified  ...
# 55                                         Hot Shot  ...
# ...                                             ...  ...
# 67494                                         Roots  ...
# 67495            Hollywood, a Beautiful Coincidence  ...
# 67496                                  Roadhouse 01  ...
# 67497                                  Good Feeling  ...
# 67498                                  Cosmic Angel  ...
#
#                            id                                   uri  \
# 0      0UaMYEvWZi0ZqiDOoHU3YI  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 6      6I9VzXrHxO9rA9A5euc8Ak  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 19     0WqIKmW4BTrj3eJFmnCKMv  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 46     1AWQoqb9bSvzTjaLralEkT  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 55     1lzr43nnXAijIGYnCT8M8H  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ...                       ...                                   ...
# 67494  3uCHI1gfOUL5j5swEh0TcH  spotify:track:3uCHI1gfOUL5j5swEh0TcH
# 67495  0P1oO2gREMYUCoOkzYAyFu  spotify:track:0P1oO2gREMYUCoOkzYAyFu
# 67496  2oM4BuruDnEvk59IvIXCwn  spotify:track:2oM4BuruDnEvk59IvIXCwn
# 67497  4Ri5TTUgjM96tbQZd5Ua7V  spotify:track:4Ri5TTUgjM96tbQZd5Ua7V
# 67498  5RVuBrXVLptAEbGJdSDzL5  spotify:track:5RVuBrXVLptAEbGJdSDzL5
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/0UaMYEvWZi0Z...
# 6      https://api.spotify.com/v1/tracks/6I9VzXrHxO9r...
# 19     https://api.spotify.com/v1/tracks/0WqIKmW4BTrj...
# 46     https://api.spotify.com/v1/tracks/1AWQoqb9bSvz...
# 55     https://api.spotify.com/v1/tracks/1lzr43nnXAij...
# ...                                                  ...
# 67494  https://api.spotify.com/v1/tracks/3uCHI1gfOUL5...
# 67495  https://api.spotify.com/v1/tracks/0P1oO2gREMYU...
# 67496  https://api.spotify.com/v1/tracks/2oM4BuruDnEv...
# 67497  https://api.spotify.com/v1/tracks/4Ri5TTUgjM96...
# 67498  https://api.spotify.com/v1/tracks/5RVuBrXVLptA...
#
#                                             analysis_url  duration_ms_y  \
# 0      https://api.spotify.com/v1/audio-analysis/0UaM...         226864
# 6      https://api.spotify.com/v1/audio-analysis/6I9V...         198800
# 19     https://api.spotify.com/v1/audio-analysis/0WqI...         235933
# 46     https://api.spotify.com/v1/audio-analysis/1AWQ...         267267
# 55     https://api.spotify.com/v1/audio-analysis/1lzr...         227600
# ...                                                  ...            ...
# 67494  https://api.spotify.com/v1/audio-analysis/3uCH...         189184
# 67495  https://api.spotify.com/v1/audio-analysis/0P1o...         263680
# 67496  https://api.spotify.com/v1/audio-analysis/2oM4...         189213
# 67497  https://api.spotify.com/v1/audio-analysis/4Ri5...         194720
# 67498  https://api.spotify.com/v1/audio-analysis/5RVu...         257195
#
#        time_signature  artist_pop  \
# 0                   4          74
# 6                   4          84
# 19                  4          86
# 46                  4          82
# 55                  4          75
# ...               ...         ...
# 67494               4          47
# 67495               4          39
# 67496               4          55
# 67497               4           4
# 67498               4          53
#
#                                                   genres  track_pop  \
# 0      dance_pop hip_hop hip_pop pop pop_rap r&b rap ...         69
# 6                            dance_pop pop post-teen_pop         83
# 19                                     dance_pop pop r&b         25
# 46                                         dance_pop pop         79
# 55                                 pop_rap reggae_fusion          2
# ...                                                  ...        ...
# 67494                                            unknown         27
# 67495                                     australian_r&b         37
# 67496  canadian_contemporary_r&b modern_alternative_rock         49
# 67497                                            unknown         16
# 67498  indie_poptimism indiecoustica modern_alternati...         40
#
#                                              artist_song
# 0      Missy ElliottLose Control (feat. Ciara & Fat M...
# 6                                    Britney SpearsToxic
# 19                                  BeyoncéCrazy In Love
# 46                       Justin TimberlakeRock Your Body
# 55                                    ShaggyIt Wasn't Me
# ...                                                  ...
# 67494                                  Jon DI Don't Know
# 67495                                Big WordsThe Answer
# 67496                                  Allan Rayman25.22
# 67497                              Jon JasonGood Feeling
# 67498  GrizfolkCosmic Angel - Acoustic From Capitol S...
#
# [34247 rows x 33 columns]

# %%
# Convert the genres column back into a list
df['genres'] = df['genres'].apply(lambda row: row.split(' '))

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# The features I will be using moving forward in the building of the recommendation system are:
#
# **Audio**
# * Danceability
# * Energy
# * Key
# * Loudness
# * Mode
# * Speechiness
# * Acousticness
# * Instrumentalness
# * Liveness
# * Valence
# * Tempo
#
# **Metadata**
# * id: The URI of the track to obtain info about it using Spotify API
# * genres: A list of genres the artists music associates with
# * artist_pop: Artist popularity (0-100)
# * track_pop: Track popularity (0-100)

# %%
# Features for consideration
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'pos', 'artist_name', 'track_uri',
#        'artist_uri', 'track_name', 'album_uri', 'duration_ms_x', 'album_name',
#        'name', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms_y', 'time_signature', 'artist_pop', 'genres', 'track_pop',
#        'artist_song'],
#       dtype='object')

# %%
# Selecting metadata and relevant features

df = df[['artist_name', 'track_name', 'danceability', 'energy', 'key', 'loudness', 'mode',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'genres', 'artist_pop', 'track_pop']]

df.head()
# Out:
#           artist_name                                  track_name  \
# 0       Missy Elliott  Lose Control (feat. Ciara & Fat Man Scoop)
# 6      Britney Spears                                       Toxic
# 19            Beyoncé                               Crazy In Love
# 46  Justin Timberlake                              Rock Your Body
# 55             Shaggy                                It Wasn't Me
#
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.904   0.813    4    -7.105     0       0.1210       0.03110
# 6          0.774   0.838    5    -3.914     0       0.1140       0.02490
# 19         0.664   0.758    2    -6.583     0       0.2100       0.00238
# 46         0.892   0.714    4    -6.055     0       0.1410       0.20100
# 55         0.853   0.606    0    -4.596     1       0.0713       0.05610
#
#     instrumentalness  liveness  valence    tempo  \
# 0           0.006970    0.0471    0.810  125.461
# 6           0.025000    0.2420    0.924  143.040
# 19          0.000000    0.0598    0.701   99.259
# 46          0.000234    0.0521    0.817  100.972
# 55          0.000000    0.3130    0.654   94.759
#
#                                                genres  artist_pop  track_pop
# 0   dance_pop hip_hop hip_pop pop pop_rap r&b rap ...          74         69
# 6                         dance_pop pop post-teen_pop          84         83
# 19                                  dance_pop pop r&b          86         25
# 46                                      dance_pop pop          82         79
# 55                              pop_rap reggae_fusion          75          2
